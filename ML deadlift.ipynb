# %%
# !pip install mediapipe opencv-python pandas scikit-learn
# Out:
# Requirement already satisfied: mediapipe in c:\users\tvfxq\anaconda3\lib\site-packages (0.8.11)
# Requirement already satisfied: opencv-python in c:\users\tvfxq\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: pandas in c:\users\tvfxq\anaconda3\lib\site-packages (1.4.4)
# Requirement already satisfied: scikit-learn in c:\users\tvfxq\anaconda3\lib\site-packages (1.0.2)
# Requirement already satisfied: opencv-contrib-python in c:\users\tvfxq\anaconda3\lib\site-packages (from mediapipe) (4.6.0.66)
# Requirement already satisfied: attrs>=19.1.0 in c:\users\tvfxq\anaconda3\lib\site-packages (from mediapipe) (21.4.0)
# Requirement already satisfied: matplotlib in c:\users\tvfxq\anaconda3\lib\site-packages (from mediapipe) (3.5.2)
# Requirement already satisfied: absl-py in c:\users\tvfxq\anaconda3\lib\site-packages (from mediapipe) (1.3.0)
# Requirement already satisfied: protobuf<4,>=3.11 in c:\users\tvfxq\anaconda3\lib\site-packages (from mediapipe) (3.20.3)
# Requirement already satisfied: numpy in c:\users\tvfxq\anaconda3\lib\site-packages (from mediapipe) (1.21.5)
# Requirement already satisfied: pytz>=2020.1 in c:\users\tvfxq\anaconda3\lib\site-packages (from pandas) (2022.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\tvfxq\anaconda3\lib\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: joblib>=0.11 in c:\users\tvfxq\anaconda3\lib\site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\tvfxq\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Requirement already satisfied: scipy>=1.1.0 in c:\users\tvfxq\anaconda3\lib\site-packages (from scikit-learn) (1.9.1)
# Requirement already satisfied: six>=1.5 in c:\users\tvfxq\anaconda3\lib\site-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\tvfxq\anaconda3\lib\site-packages (from matplotlib->mediapipe) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\tvfxq\anaconda3\lib\site-packages (from matplotlib->mediapipe) (9.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\tvfxq\anaconda3\lib\site-packages (from matplotlib->mediapipe) (1.4.2)
# Requirement already satisfied: cycler>=0.10 in c:\users\tvfxq\anaconda3\lib\site-packages (from matplotlib->mediapipe) (0.11.0)
# Requirement already satisfied: pyparsing>=2.2.1 in c:\users\tvfxq\anaconda3\lib\site-packages (from matplotlib->mediapipe) (3.0.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\tvfxq\anaconda3\lib\site-packages (from matplotlib->mediapipe) (21.3)

# %%
import mediapipe as mp
import cv2
import numpy as np

# %%
mp_drawing = mp.solutions.drawing_utils
mp_pose = mp.solutions.pose

# %%
cap = cv2.VideoCapture(0)
## 미디어 파이프 instance 결정
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        
        # 이미지를 다시 RGB형식으로 칠함 (먼저는 프레임을 잡아줘야한다)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False # 이미지 다시쓰기
      
        # 탐지하기
        results = pose.process(image)
    
        # 이미지를 RGB로 나타냄
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) 
                                 )               
        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(10) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()

# %%
cap = cv2.VideoCapture(0)

height = cap.get(cv2.CAP_PROP_FRAME_HEIGHT)
width = cap.get(cv2.CAP_PROP_FRAME_WIDTH)
fps = cap.get(cv2.CAP_PROP_FPS)
videoWriter = cv2.VideoWriter('press.avi', cv2.VideoWriter_fourcc(*'DIVX'), fps, (int(width),int(height)))

cv2.VideoCapture()
## 미디어 파이프 instance 결정

while cap.isOpened(): 
    ret, frame = cap.read()
        
    try:
        cv2.imshow('Press',frame)
        videoWriter.write(frame)
    except Exception as e:
        break

    if cv2.waitKey(10) & 0xFF == ord('q'):
        break
cap.release()
videoWriter.release()
cv2.destroyAllWindows()

# %%
import csv
import os
import numpy as np
from matplotlib import pyplot as plt

# %%
landmarks = ['class']
for val in range(1,33+1):
    landmarks += ['x{}'.format(val),'y{}'.format(val),'z{}'.format(val),'v{}'.format(val)]

# %%
landmarks[1:]
# Out:
# ['x1',
#  'y1',
#  'z1',
#  'v1',
#  'x2',
#  'y2',
#  'z2',
#  'v2',
#  'x3',
#  'y3',
#  'z3',
#  'v3',
#  'x4',
#  'y4',
#  'z4',
#  'v4',
#  'x5',
#  'y5',
#  'z5',
#  'v5',
#  'x6',
#  'y6',
#  'z6',
#  'v6',
#  'x7',
#  'y7',
#  'z7',
#  'v7',
#  'x8',
#  'y8',
#  'z8',
#  'v8',
#  'x9',
#  'y9',
#  'z9',
#  'v9',
#  'x10',
#  'y10',
#  'z10',
#  'v10',
#  'x11',
#  'y11',
#  'z11',
#  'v11',
#  'x12',
#  'y12',
#  'z12',
#  'v12',
#  'x13',
#  'y13',
#  'z13',
#  'v13',
#  'x14',
#  'y14',
#  'z14',
#  'v14',
#  'x15',
#  'y15',
#  'z15',
#  'v15',
#  'x16',
#  'y16',
#  'z16',
#  'v16',
#  'x17',
#  'y17',
#  'z17',
#  'v17',
#  'x18',
#  'y18',
#  'z18',
#  'v18',
#  'x19',
#  'y19',
#  'z19',
#  'v19',
#  'x20',
#  'y20',
#  'z20',
#  'v20',
#  'x21',
#  'y21',
#  'z21',
#  'v21',
#  'x22',
#  'y22',
#  'z22',
#  'v22',
#  'x23',
#  'y23',
#  'z23',
#  'v23',
#  'x24',
#  'y24',
#  'z24',
#  'v24',
#  'x25',
#  'y25',
#  'z25',
#  'v25',
#  'x26',
#  'y26',
#  'z26',
#  'v26',
#  'x27',
#  'y27',
#  'z27',
#  'v27',
#  'x28',
#  'y28',
#  'z28',
#  'v28',
#  'x29',
#  'y29',
#  'z29',
#  'v29',
#  'x30',
#  'y30',
#  'z30',
#  'v30',
#  'x31',
#  'y31',
#  'z31',
#  'v31',
#  'x32',
#  'y32',
#  'z32',
#  'v32',
#  'x33',
#  'y33',
#  'z33',
#  'v33']

# %%
 with open('coords.csv',mode = 'w', newline ='') as f:
        csv_writer = csv.writer(f, delimiter =',',quotechar = '"', quoting = csv.QUOTE_MINIMAL)
        csv_writer.writerow(landmarks)

# %%
def export_landmark(results, action):
    try:
        keypoints = np.array([[res.x, res.y, res.z, res.visibility] for res in results.pose_landmarks.landmark]).flatten().tolist()
        keypoints.insert(0, action)
        
            csv_writer = csv.writer(f, delimiter=',', quotechar='"', quoting=csv.QUOTE_MINIMAL)
            csv_writer.writerow(keypoints)
            
     except Exception as e:
        pass

# %%
results
# Out:
# mediapipe.python.solution_base.SolutionOutputs

# %%
results.pose_landmarks
# Out:
# landmark {
#   x: 0.5372301340103149
#   y: 0.539031982421875
#   z: -2.2252771854400635
#   visibility: 0.9979203939437866
# }
# landmark {
#   x: 0.5691796541213989
#   y: 0.4631085991859436
#   z: -2.1847422122955322
#   visibility: 0.996446430683136
# }
# landmark {
#   x: 0.5932080149650574
#   y: 0.4618303179740906
#   z: -2.185218334197998
#   visibility: 0.996907651424408
# }
# landmark {
#   x: 0.6126317381858826
#   y: 0.46122053265571594
#   z: -2.185788869857788
#   visibility: 0.9966422319412231
# }
# landmark {
#   x: 0.49913278222084045
#   y: 0.46998053789138794
#   z: -2.1644978523254395
#   visibility: 0.9962770938873291
# }
# landmark {
#   x: 0.4782488942146301
#   y: 0.4729515612125397
#   z: -2.164445161819458
#   visibility: 0.9966108202934265
# }
# landmark {
#   x: 0.46138906478881836
#   y: 0.47628602385520935
#   z: -2.1652534008026123
#   visibility: 0.9967437386512756
# }
# landmark {
#   x: 0.6451079249382019
#   y: 0.4815353453159332
#   z: -1.653656005859375
#   visibility: 0.9973762035369873
# }
# landmark {
#   x: 0.4385634958744049
#   y: 0.5003484487533569
#   z: -1.54426109790802
#   visibility: 0.9975494742393494
# }
# landmark {
#   x: 0.5951385498046875
#   y: 0.6278688907623291
#   z: -2.001927375793457
#   visibility: 0.9986040592193604
# }
# landmark {
#   x: 0.5009352564811707
#   y: 0.6351819634437561
#   z: -1.9723584651947021
#   visibility: 0.9987915754318237
# }
# landmark {
#   x: 0.8478080630302429
#   y: 0.8333975672721863
#   z: -1.115408182144165
#   visibility: 0.9931391477584839
# }
# landmark {
#   x: 0.2961549162864685
#   y: 0.8414192795753479
#   z: -0.9470034837722778
#   visibility: 0.9962596893310547
# }
# landmark {
#   x: 0.9530696868896484
#   y: 1.294521450996399
#   z: -0.9894086718559265
#   visibility: 0.4008164703845978
# }
# landmark {
#   x: 0.19304291903972626
#   y: 1.2486283779144287
#   z: -0.6357340216636658
#   visibility: 0.35441964864730835
# }
# landmark {
#   x: 0.9457076191902161
#   y: 1.6785727739334106
#   z: -1.4215432405471802
#   visibility: 0.04871302470564842
# }
# landmark {
#   x: 0.20121267437934875
#   y: 1.6341569423675537
#   z: -1.1460710763931274
#   visibility: 0.058707259595394135
# }
# landmark {
#   x: 0.9716267585754395
#   y: 1.8071423768997192
#   z: -1.5725739002227783
#   visibility: 0.051211100071668625
# }
# landmark {
#   x: 0.18262436985969543
#   y: 1.773141622543335
#   z: -1.319846510887146
#   visibility: 0.060620129108428955
# }
# landmark {
#   x: 0.9343324899673462
#   y: 1.801626205444336
#   z: -1.7117305994033813
#   visibility: 0.07754410058259964
# }
# landmark {
#   x: 0.21778538823127747
#   y: 1.7634577751159668
#   z: -1.4716801643371582
#   visibility: 0.09358390420675278
# }
# landmark {
#   x: 0.9103458523750305
#   y: 1.748561143875122
#   z: -1.496215581893921
#   visibility: 0.06892134994268417
# }
# landmark {
#   x: 0.23729217052459717
#   y: 1.710526943206787
#   z: -1.2309924364089966
#   visibility: 0.08648520708084106
# }
# landmark {
#   x: 0.7303673028945923
#   y: 1.7085750102996826
#   z: -0.08180075138807297
#   visibility: 0.0016011357074603438
# }
# landmark {
#   x: 0.3852918744087219
#   y: 1.6831626892089844
#   z: 0.08773943036794662
#   visibility: 0.0015361161204054952
# }
# landmark {
#   x: 0.7047890424728394
#   y: 2.4298675060272217
#   z: -0.41928595304489136
#   visibility: 0.004909866023808718
# }
# landmark {
#   x: 0.3808044493198395
#   y: 2.3593368530273438
#   z: -0.4800470471382141
#   visibility: 0.002843476366251707
# }
# landmark {
#   x: 0.7117859721183777
#   y: 3.095425605773926
#   z: 0.23908992111682892
#   visibility: 0.00022640539100393653
# }
# landmark {
#   x: 0.39875516295433044
#   y: 3.0451207160949707
#   z: -0.028625210747122765
#   visibility: 0.00018102279864251614
# }
# landmark {
#   x: 0.7165349721908569
#   y: 3.209683656692505
#   z: 0.2524648904800415
#   visibility: 0.00010270650091115385
# }
# landmark {
#   x: 0.4018472731113434
#   y: 3.1615419387817383
#   z: -0.016696888953447342
#   visibility: 0.000243717004195787
# }
# landmark {
#   x: 0.6648097038269043
#   y: 3.2846715450286865
#   z: -0.629252016544342
#   visibility: 0.0003686814452521503
# }
# landmark {
#   x: 0.4495352804660797
#   y: 3.2417571544647217
#   z: -0.9296261072158813
#   visibility: 0.0009287159191444516
# }

# %%
export_landmark(results,'up')

# %%
cap = cv2.VideoCapture('press.avi')
## 미디어 파이프 instance 결정
with mp_pose.Pose(min_detection_confidence=0.5, min_tracking_confidence=0.5) as pose:
    while cap.isOpened():
        ret, frame = cap.read()
        if not ret:
            break
        
        # 이미지를 다시 RGB형식으로 칠함 (먼저는 프레임을 잡아줘야한다)
        image = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
        image.flags.writeable = False # 이미지 다시쓰기
      
        # 탐지하기
        results = pose.process(image)
    
        # 이미지를 RGB로 나타냄
        image.flags.writeable = True
        image = cv2.cvtColor(image, cv2.COLOR_RGB2BGR)
        
        # Render detections
        mp_drawing.draw_landmarks(image, results.pose_landmarks, mp_pose.POSE_CONNECTIONS,
                                mp_drawing.DrawingSpec(color=(245,117,66), thickness=2, circle_radius=2), 
                                mp_drawing.DrawingSpec(color=(245,66,230), thickness=2, circle_radius=2) 
                                 )
        k = cv2.waitKey(1)
        if k == 117:
            export_landmark(results,'up')
        if k == 100:
            export_landmark(results,'down')
        
        cv2.imshow('Raw Webcam Feed', image)

        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    cap.release()
    cv2.destroyAllWindows()
