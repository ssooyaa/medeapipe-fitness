# %%
from bs4 import BeautifulSoup
from selenium import webdriver
import pandas as pd
import time
from selenium.webdriver.common.keys import Keys
keys=Keys()

# %%
driver = webdriver.Chrome("C:/py_data/chromedriver.exe")

# %%
keyword = "파이썬"

# %%
driver.get('https://section.cafe.naver.com/')

# %%
driver.find_element_by_css_selector('#header > div.snb_area > div > div.SearchArea > form > fieldset > div > div > div.FormInputText > input').click()
#elements하면 전체를 리스트로 가져옴

# %%
driver.find_element_by_css_selector('#header > div.snb_area > div > div.SearchArea > form > fieldset > div > div > div.FormInputText > input').send_keys(keyword)

# %%
driver.find_element_by_css_selector('#header > div.snb_area > div > div.SearchArea > form > fieldset > div > div > div.FormInputText > input').send_keys(keys.ENTER)

# %%
driver.find_element_by_css_selector('#mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.list_area.article_list_area > div > a > span').click()

# %%
driver.find_element_by_css_selector('#mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child(1) > div > div > div > a')
driver.find_element_by_css_selector('#mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child(2) > div > div > div > a')

# %%
for i  in range(1,13):
    print('#mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child('+str(i)+') > div > div > div > a')
# Out:
# #mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child(1) > div > div > div > a
# #mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child(2) > div > div > div > a
# #mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child(3) > div > div > div > a
# #mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child(4) > div > div > div > a
# #mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child(5) > div > div > div > a
# #mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child(6) > div > div > div > a
# ...

# %%
driver.find_element_by_css_selector('#mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child(1) > div > div > div > a').click()

# %%
driver.switch_to.window(driver.window_handles[-1])

# %%
driver.current_url
# Out:
# 'https://cafe.naver.com/carroty/372577?art=aW50ZXJuYWwtY2FmZS13ZWItc2VjdGlvbi1zZWFyY2gtbGlzdA.eyJ0eXAiOiJKV1QiLCJhbGciOiJIUzI1NiJ9.eyJjYWZlVHlwZSI6IkNBRkVfVVJMIiwiYXJ0aWNsZUlkIjozNzI1NzcsImNhZmVVcmwiOiJjYXJyb3R5IiwiaXNzdWVkQXQiOjE2NjExNDM2MTE1OTl9.OQ7zO9UmmH9gdW9H1hX4dy1_Tk_6fO0zuHVgA2wZPFw'

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
soup
# Out:
# <html lang="ko"><head>
# <meta content="noindex, nofollow" name="robots"/>
# <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
# <meta content="requiresActiveX=true" http-equiv="X-UA-Compatible"/>
# <title>라즈베리파이 피코 , 마이크로 파이썬 GPIO 번호 읽는 법? : 네이버 카페</title>
# <link href="/favicon.ico?2" rel="shortcut icon" type="image/x-icon"/>
# <meta content="always" name="referrer"/>
# <link href="/static/css/main/css/line_sticker-1644284985000-9453.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/main/css/comment-1644284985000-17199.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/main/css/map/cafe_map-1644284985000-14563.css" rel="stylesheet" type="text/css"/>
# <style id="cafeCss" type="text/css">
# </style>
# <link href="/static/css/main/css/wide/1080_cafe-1656926234000-227641.css" rel="stylesheet" type="text/css"/>
# <link href="/static/css/main/css/wide/1080_skin_white-1644284985000-20365.css" rel="stylesheet" type="text/css"/>
# <script>
# ...

# %%
driver.switch_to_frame('cafe_main')

# %%
html = driver.page_source
soup = BeautifulSoup(html, 'html.parser')
print(soup)
# Out:
# <html lang="ko" theme="white"><head><script defer="" src="https://cafe.like.naver.com/js/reaction/dist/reaction.min.js?1661144968108" type="text/javascript"></script><script defer="" src="https://ssl.pstatic.net/tveta/libs/ssp/ssp.web.sdk.js" type="text/javascript"></script><script charset="utf-8" defer="" src="https://editor-static.pstatic.net/v/basic/1.33.0/se.viewer.js" type="text/javascript"></script><link href="https://editor-static.pstatic.net/v/basic/1.33.0/css/se.viewer.desktop.css" rel="stylesheet"/><meta charset="utf-8"/><meta content="text/html; charset=utf-8" http-equiv="Content-Type"/><meta content="IE=edge" http-equiv="X-UA-Compatible"/><meta content="noindex, nofollow" name="robots"/><meta content="width=device-width,initial-scale=1" name="viewport"/><link href="https://ca-fe.pstatic.net/web-pc/favicon.ico" rel="icon"/><title>네이버 카페</title><link href="https://ca-fe.pstatic.net/web-pc/css/app.c55f4038.css" rel="stylesheet"/><style>:root{--themeColorTC1: #000;--themeColo
# ...

# %%
title = soup.find('h3', class_='title_text').text

# %%
import re  #정규표현식
title = re.sub('[^ㄱ-ㅣ가-힣 ]',"",title)
title
# Out:
# '            라즈베리파이 피코  마이크로 파이썬  번호 읽는 법        '

# %%
title.strip()
# Out:
# '라즈베리파이 피코  마이크로 파이썬  번호 읽는 법'

# %%
count = soup.find('div', class_= 'se-component-content').text
count
# Out:
# '\n\n\n안녕하세요 라즈베리파이 피코 로 마이크로 파이썬 코딩중입니다.\u200b아래와 같이 GPIO 설정한 후에 GPIO 핀 ID 를 읽으려고하는데 잘안됩니다.\u200b조언부탁드립니다.\u200b\n\n\n'

# %%
count = re.sub('[^ㄱ-ㅣ가-힣a-zA-Z ]',"",count)
count
# Out:
# '안녕하세요 라즈베리파이 피코 로 마이크로 파이썬 코딩중입니다아래와 같이 GPIO 설정한 후에 GPIO 핀 ID 를 읽으려고하는데 잘안됩니다조언부탁드립니다'

# %%
comment_lst = soup.find_all('span', class_='text_comment')
comment_lst
# Out:
# [<span class="text_comment"><a href="http://sw_menu.value" target="_blank">sw_menu.value</a>() 형식으로 읽으면 됩니다. inpit pin에 pull-up or pull-down 처리는 하셨나요?</span>,
#  <span class="text_comment">value 는 GPIO 상태 low,high return 입니다.<br/>GPIO ID , 위 글에서 20번 포트라는 것을 역으로 Reading 하고자합니다.</span>,
#  <span class="text_comment"></span>,
#  <span class="text_comment">제가 질문을 잘못 이해했네요.</span>,
#  <span class="text_comment"><a href="http://sw_menu.id" target="_blank">sw_menu.id</a> 나 <a href="http://sw_menu.id" target="_blank">sw_menu.id</a>()<br/>로 되지 않을까요?<br/><a href="https://docs.micropython.org/en/latest/library/machine.Pin.html" target="_blank">https://docs.micropython.org/en/latest/library/machine.Pin.html</a></span>,
#  <span class="text_comment">안되더라고요 ㅠㅡㅠ</span>,
#  <span class="text_comment"><br/><a href="https://www.denshi.club/parts/2021/04/raspberry-pi-pico-16-gpio.html" target="_blank">https://www.denshi.club/parts/2021/04/raspberry-pi-pico-16-gpio.html</a><br/>참고 하세요<br/></span>,
# ...

# %%
comment = ''
for txt in comment_lst:
    comment = comment + " " + txt.text

# %%
comment
# Out:
# " sw_menu.value() 형식으로 읽으면 됩니다. inpit pin에 pull-up or pull-down 처리는 하셨나요? value 는 GPIO 상태 low,high return 입니다.GPIO ID , 위 글에서 20번 포트라는 것을 역으로 Reading 하고자합니다.  제가 질문을 잘못 이해했네요. sw_menu.id 나 sw_menu.id()로 되지 않을까요?https://docs.micropython.org/en/latest/library/machine.Pin.html 안되더라고요 ㅠㅡㅠ https://www.denshi.club/parts/2021/04/raspberry-pi-pico-16-gpio.html참고 하세요 dir(sw_menu)로 객체 멤버를 출력해보면 핀번호가 없네요. 하지만 아래와 같은 방법들로 구현하면 가능할 것 같긴 합니다.1. 다음 링크에 나온 것처럼 micropython 소스코드를 수정하여 pin() 과 같은 메소드를 추가합니다. 그리고, 펌웨어 소스를 빌드하여 업로드합니다.https://github.com/micropython/micropython/pull/70052. pin 객체를 출력해 보면 아시겠지만 Pin(20, mode=IN..) 이런식으로 출력되니까 아래와 같은 식으로 변환합니다. 그런데 좋은 방법 같지는 않네요.id = int( str(sw_menu).split(',')[0][4:])3. 딕셔너리를 하나 만들고 pin 을 생성할 때마다 등록한 후에, 나중에 참조하면 됩니다.pinid={}...pinid[id(sw_menu)] = 20...def irq(pin):____id = pinid[id(pin)] dir 기능 궁금했는데 객체맴버 출력함수군요 활용해봐야겠습니다. \n\nmicropyhon 소스코드 어디서 수정해야하는지 몰랐는데 한번 도전해봐야겠네요\n\n조언 너무 감사드립니다. \n어렵지만 답은 여기있을 것같습니다"

# %%
driver.close()

# %%
driver.current_url #보고있던 것 닫아서 에러남
# Out:
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [36], in <cell line: 1>()
# ----> 1 driver.current_url
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:491, in WebDriver.current_url(self)
#     483 @property
#     484 def current_url(self):
#     485     """
#     486     Gets the URL of the current page.
#     487
#     488     :Usage:
#     489         driver.current_url
#     490     """
# --> 491     return self.execute(Command.GET_CURRENT_URL)['value']
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:236, in WebDriver.execute(self, driver_command, params)
#     234 response = self.command_executor.execute(driver_command, params)
#     235 if response:
# --> 236     self.error_handler.check_response(response)
#     237     response['value'] = self._unwrap_value(
# ...

# %%
driver.switch_to.window(driver.window_handles[0])

# %%
driver.current_url
# Out:
# 'https://section.cafe.naver.com/ca-fe/home/search/articles?q=%ED%8C%8C%EC%9D%B4%EC%8D%AC'

# %%
for i in range(1,13):
    driver.find_element_by_css_selector('#mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child('+str(i)+') > div > div > div > a').click()
    driver.switch_to.window(driver.window_handles[-1])
    title = re.sub('[^ㄱ-ㅣ가-힣 ]',"",title)

# %%
driver = webdriver.Chrome("C:/py_data/chromedriver.exe")
title_lst = []
content_lst = []
comment_lst = []
driver.get('https://section.cafe.naver.com/ca-fe/home/search/articles?q=파이썬')

# %%
driver.current_url
# Out:
# 'https://section.cafe.naver.com/ca-fe/home/search/articles?q=%ED%8C%8C%EC%9D%B4%EC%8D%AC'

# %%
driver.find_element_by_css_selector('#mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child(1) > div > div > div > a').click()

# %%
driver = webdriver.Chrome("C:/py_data/chromedriver.exe")
title_lst = []
content_lst = []
comment_lst = []
driver.get('https://section.cafe.naver.com/ca-fe/home/search/articles?q=파이썬')
for i  in range(1,13):
    driver.find_element_by_css_selector('#mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child('&i&') > div > div > div > a').click()
    driver.switch_to.window(driver.window_handles[-1])
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    driver.switch_to_frame('cafe_main')
    html = driver.page_source
    soup = BeautifulSoup(html, 'html.parser')
    title = soup.find('h3', class_='title_text').text
    title = re.sub('[^ㄱ-ㅣ가-힣 ]',"",title)
    title_lst.append(title.strip())
    content = soup.find('div', class_= 'se-component-content').text
    content = re.sub('[^ㄱ-ㅣ가-힣a-zA-Z ]',"",content)
    content_lst.append(content)
    comment_lst = soup.find_all('span', class_='text_comment')
    comment = ''
    for txt in comment_lst:
        comment = comment + " " + txt.text
        driver.close()
        driver.switch_to.window(driver.window_handles[0])
            
cafe_df = pd.DataFrame({'제목':title_lst,'본문':content_lst,'댓글':comment_lst})
cafe_df.to_csv("c:/py_data/파이썬 카페 검색 결과(비로그인).csv",encoding='cp949')
driver.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [45], in <cell line: 6>()
#       5 driver.get('https://section.cafe.naver.com/ca-fe/home/search/articles?q=파이썬')
#       6 for i  in range(1,13):
# ----> 7     driver.find_element_by_css_selector('#mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child('&i&') > div > div > div > a').click()
#       8     driver.switch_to.window(driver.window_handles[-1])
#       9     html = driver.page_source
#
# TypeError: unsupported operand type(s) for &: 'str' and 'int'

# %%
driver = webdriver.Chrome("C:/py_data/chromedriver.exe")
title_lst = []
content_lst = []
comment_lst = []
for i in ['','&p=2','&p=3']:
    driver.get('https://section.cafe.naver.com/ca-fe/home/search/articles?q=파이썬' + i)
    for k in range(1,13):
        driver.find_element_by_css_selector('#mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child(' +str(k)+ ') > div > div > div > a').click()
        driver.switch_to.window(driver.window_handles[-1])
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        driver.switch_to_frame('cafe_main')
        html = driver.page_source
        soup = BeautifulSoup(html, 'html.parser')
        title = soup.find('h3', class_='title_text').text
        title = re.sub('[^ㄱ-ㅣ가-힣 ]',"",title)
        title_lst.append(title.strip())
        content = soup.find('div', class_= 'se-component-content').text
        content = re.sub('[^ㄱ-ㅣ가-힣a-zA-Z ]',"",content)
        content_lst.append(content)
        driver.close()
        driver.switch_to.window(driver.window_handles[0])
        
cafe_df = pd.DataFrame({'제목':title_lst,'본문':content_lst})
cafe_df.to_csv("c:/py_data/파이썬 카페 검색 결과(비로그인).csv",encoding='cp949')
# Out:
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [47], in <cell line: 5>()
#       6 driver.get('https://section.cafe.naver.com/ca-fe/home/search/articles?q=파이썬' + i)
#       7 for k in range(1,13):
# ----> 8     driver.find_element_by_css_selector('#mainContainer > div > div.SectionSearchContent > div.section_search_content > div > div.article_list_area > ul > li:nth-child(' +str(k)+ ') > div > div > div > a').click()
#       9     driver.switch_to.window(driver.window_handles[-1])
#      10     html = driver.page_source
#
# File ~\anaconda3\lib\site-packages\selenium\webdriver\remote\webdriver.py:437, in WebDriver.find_element_by_css_selector(self, css_selector)
#     427 def find_element_by_css_selector(self, css_selector):
#     428     """
#     429     Finds an element by css selector.
#     430
#    (...)
# ...
